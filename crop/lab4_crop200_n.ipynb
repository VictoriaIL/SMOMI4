# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 39kB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 44.4MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.5)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 43.1MB/s
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14) (47.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
import os
os.chdir("/content/drive/My Drive/СМОМИ/Лаба 4")
# !ls
# Out:
# images	lab4_crop200.ipynb  logs  model.h5

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
import math
from tensorflow.python import keras as keras
from keras.models import load_model
from numpy import asarray
import PIL
from PIL import Image
import random


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    return example['image'], example['image/class/label']


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .repeat()\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def create_aug_dataset(filenames, batch_size):
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(augment)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .repeat()\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def augment(image,label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.random_crop(image, size=[200, 200, 3], seed=None, name=None)
    return image,label

class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })


def build_model():
    model = keras.models.load_model('model.h5')
    model.trainable = True
    return model


def main():
    train_path = './images/train*'
    test_path = './images/test*'
    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)


    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=1e-11, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=130,
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1217 - categorical_accuracy: 0.2886The average loss for epoch 0 is    0.12
# 78/78 [==============================] - 15s 189ms/step - loss: 0.1303 - categorical_accuracy: 0.3109
# 652/652 [==============================] - 101s 155ms/step - loss: 0.1215 - categorical_accuracy: 0.2882
# Epoch 2/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1252 - categorical_accuracy: 0.2969The average loss for epoch 1 is    0.13
# 78/78 [==============================] - 15s 188ms/step - loss: 0.2322 - categorical_accuracy: 0.5609
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1257 - categorical_accuracy: 0.2979
# Epoch 3/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1224 - categorical_accuracy: 0.2949The average loss for epoch 2 is    0.12
# 78/78 [==============================] - 19s 246ms/step - loss: 0.3413 - categorical_accuracy: 0.5785
# 652/652 [==============================] - 102s 156ms/step - loss: 0.1223 - categorical_accuracy: 0.2945
# Epoch 4/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1239 - categorical_accuracy: 0.2972The average loss for epoch 3 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0973 - categorical_accuracy: 0.2901
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1244 - categorical_accuracy: 0.2983
# Epoch 5/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1232 - categorical_accuracy: 0.2976The average loss for epoch 4 is    0.12
# 78/78 [==============================] - 13s 160ms/step - loss: 0.1310 - categorical_accuracy: 0.4663
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1237 - categorical_accuracy: 0.2985
# Epoch 6/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2928The average loss for epoch 5 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2019
# 652/652 [==============================] - 93s 142ms/step - loss: 0.1214 - categorical_accuracy: 0.2926
# Epoch 7/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1239 - categorical_accuracy: 0.2842The average loss for epoch 6 is    0.12
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2019
# 652/652 [==============================] - 92s 142ms/step - loss: 0.1237 - categorical_accuracy: 0.2839
# Epoch 8/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1232 - categorical_accuracy: 0.2865The average loss for epoch 7 is    0.12
# 78/78 [==============================] - 12s 149ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2019
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1230 - categorical_accuracy: 0.2860
# Epoch 9/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.2984The average loss for epoch 8 is    0.12
# 78/78 [==============================] - 16s 206ms/step - loss: 0.2142 - categorical_accuracy: 0.3974
# 652/652 [==============================] - 101s 154ms/step - loss: 0.1218 - categorical_accuracy: 0.2981
# Epoch 10/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1248 - categorical_accuracy: 0.2944The average loss for epoch 9 is    0.13
# 78/78 [==============================] - 13s 164ms/step - loss: 0.1448 - categorical_accuracy: 0.4696
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1254 - categorical_accuracy: 0.2952
# Epoch 11/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2919The average loss for epoch 10 is    0.12
# 78/78 [==============================] - 21s 266ms/step - loss: 0.3731 - categorical_accuracy: 0.6891
# 652/652 [==============================] - 105s 161ms/step - loss: 0.1223 - categorical_accuracy: 0.2914
# Epoch 12/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.2947The average loss for epoch 11 is    0.12
# 78/78 [==============================] - 14s 177ms/step - loss: 0.1527 - categorical_accuracy: 0.3269
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1219 - categorical_accuracy: 0.2945
# Epoch 13/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1256 - categorical_accuracy: 0.2955The average loss for epoch 12 is    0.13
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0691 - categorical_accuracy: 0.3157
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1262 - categorical_accuracy: 0.2966
# Epoch 14/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1228 - categorical_accuracy: 0.2911The average loss for epoch 13 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 94s 143ms/step - loss: 0.1226 - categorical_accuracy: 0.2906
# Epoch 15/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1226 - categorical_accuracy: 0.2874The average loss for epoch 14 is    0.12
# 78/78 [==============================] - 12s 159ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1224 - categorical_accuracy: 0.2872
# Epoch 16/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2974The average loss for epoch 15 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1223 - categorical_accuracy: 0.2972
# Epoch 17/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1210 - categorical_accuracy: 0.2928The average loss for epoch 16 is    0.12
# 78/78 [==============================] - 17s 212ms/step - loss: 0.2900 - categorical_accuracy: 0.4984
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1208 - categorical_accuracy: 0.2924
# Epoch 18/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1251 - categorical_accuracy: 0.2913The average loss for epoch 17 is    0.13
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0809 - categorical_accuracy: 0.3413
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1255 - categorical_accuracy: 0.2924
# Epoch 19/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1246 - categorical_accuracy: 0.2926The average loss for epoch 18 is    0.12
# 78/78 [==============================] - 20s 251ms/step - loss: 0.3337 - categorical_accuracy: 0.7163
# 652/652 [==============================] - 104s 160ms/step - loss: 0.1249 - categorical_accuracy: 0.2935
# Epoch 20/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1209 - categorical_accuracy: 0.2924The average loss for epoch 19 is    0.12
# 78/78 [==============================] - 16s 202ms/step - loss: 0.2241 - categorical_accuracy: 0.4295
# 652/652 [==============================] - 99s 151ms/step - loss: 0.1208 - categorical_accuracy: 0.2924
# Epoch 21/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1235 - categorical_accuracy: 0.2926The average loss for epoch 20 is    0.12
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0111 - categorical_accuracy: 0.2115
# 652/652 [==============================] - 96s 146ms/step - loss: 0.1233 - categorical_accuracy: 0.2926
# Epoch 22/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1219 - categorical_accuracy: 0.2909The average loss for epoch 21 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1217 - categorical_accuracy: 0.2905
# Epoch 23/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1219 - categorical_accuracy: 0.2936The average loss for epoch 22 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 94s 145ms/step - loss: 0.1217 - categorical_accuracy: 0.2933
# Epoch 24/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1254 - categorical_accuracy: 0.2844The average loss for epoch 23 is    0.13
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1252 - categorical_accuracy: 0.2839
# Epoch 25/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1234 - categorical_accuracy: 0.2880The average loss for epoch 24 is    0.12
# 78/78 [==============================] - 18s 229ms/step - loss: 0.3653 - categorical_accuracy: 0.6314
# 652/652 [==============================] - 101s 154ms/step - loss: 0.1232 - categorical_accuracy: 0.2878
# Epoch 26/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1242 - categorical_accuracy: 0.3015The average loss for epoch 25 is    0.12
# 78/78 [==============================] - 13s 168ms/step - loss: 0.1119 - categorical_accuracy: 0.2628
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1243 - categorical_accuracy: 0.3016
# Epoch 27/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1254 - categorical_accuracy: 0.2955The average loss for epoch 26 is    0.13
# 78/78 [==============================] - 17s 224ms/step - loss: 0.2590 - categorical_accuracy: 0.6202
# 652/652 [==============================] - 101s 155ms/step - loss: 0.1260 - categorical_accuracy: 0.2964
# Epoch 28/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1219 - categorical_accuracy: 0.2947The average loss for epoch 27 is    0.12
# 78/78 [==============================] - 15s 191ms/step - loss: 0.2297 - categorical_accuracy: 0.4872
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1217 - categorical_accuracy: 0.2945
# Epoch 29/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1211 - categorical_accuracy: 0.2957The average loss for epoch 28 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 8.0588e-04 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 91s 140ms/step - loss: 0.1209 - categorical_accuracy: 0.2956
# Epoch 30/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1204 - categorical_accuracy: 0.2901The average loss for epoch 29 is    0.12
# 78/78 [==============================] - 13s 160ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1202 - categorical_accuracy: 0.2897
# Epoch 31/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1211 - categorical_accuracy: 0.2876The average loss for epoch 30 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1209 - categorical_accuracy: 0.2872
# Epoch 32/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1217 - categorical_accuracy: 0.3001The average loss for epoch 31 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 94s 145ms/step - loss: 0.1215 - categorical_accuracy: 0.2997
# Epoch 33/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1215 - categorical_accuracy: 0.2926The average loss for epoch 32 is    0.12
# 78/78 [==============================] - 18s 226ms/step - loss: 0.3588 - categorical_accuracy: 0.7324
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1213 - categorical_accuracy: 0.2922
# Epoch 34/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.2930The average loss for epoch 33 is    0.12
# 78/78 [==============================] - 14s 184ms/step - loss: 0.1810 - categorical_accuracy: 0.3494
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1212 - categorical_accuracy: 0.2926
# Epoch 35/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1233 - categorical_accuracy: 0.3013The average loss for epoch 34 is    0.12
# 78/78 [==============================] - 15s 198ms/step - loss: 0.1847 - categorical_accuracy: 0.5016
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1239 - categorical_accuracy: 0.3023
# Epoch 36/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.2978The average loss for epoch 35 is    0.12
# 78/78 [==============================] - 14s 185ms/step - loss: 0.2156 - categorical_accuracy: 0.5144
# 652/652 [==============================] - 94s 145ms/step - loss: 0.1229 - categorical_accuracy: 0.2974
# Epoch 37/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1221 - categorical_accuracy: 0.2967The average loss for epoch 36 is    0.12
# 78/78 [==============================] - 12s 151ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 92s 140ms/step - loss: 0.1219 - categorical_accuracy: 0.2964
# Epoch 38/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1206 - categorical_accuracy: 0.2959The average loss for epoch 37 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 91s 140ms/step - loss: 0.1204 - categorical_accuracy: 0.2958
# Epoch 39/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.2957The average loss for epoch 38 is    0.12
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1219 - categorical_accuracy: 0.2954
# Epoch 40/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1238 - categorical_accuracy: 0.2940The average loss for epoch 39 is    0.12
# 78/78 [==============================] - 12s 153ms/step - loss: 0.0333 - categorical_accuracy: 0.2179
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1236 - categorical_accuracy: 0.2935
# Epoch 41/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1250 - categorical_accuracy: 0.2936The average loss for epoch 40 is    0.13
# 78/78 [==============================] - 16s 203ms/step - loss: 0.3079 - categorical_accuracy: 0.6827
# 652/652 [==============================] - 99s 151ms/step - loss: 0.1255 - categorical_accuracy: 0.2947
# Epoch 42/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2955The average loss for epoch 41 is    0.12
# 78/78 [==============================] - 16s 211ms/step - loss: 0.2525 - categorical_accuracy: 0.4728
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1220 - categorical_accuracy: 0.2951
# Epoch 43/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1249 - categorical_accuracy: 0.2924The average loss for epoch 42 is    0.13
# 78/78 [==============================] - 15s 190ms/step - loss: 0.1015 - categorical_accuracy: 0.3942
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1253 - categorical_accuracy: 0.2935
# Epoch 44/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2967The average loss for epoch 43 is    0.12
# 78/78 [==============================] - 14s 185ms/step - loss: 0.2020 - categorical_accuracy: 0.5304
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1221 - categorical_accuracy: 0.2966
# Epoch 45/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1212 - categorical_accuracy: 0.2942The average loss for epoch 44 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1210 - categorical_accuracy: 0.2941
# Epoch 46/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1210 - categorical_accuracy: 0.2974The average loss for epoch 45 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1208 - categorical_accuracy: 0.2970
# Epoch 47/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.2942The average loss for epoch 46 is    0.12
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1212 - categorical_accuracy: 0.2939
# Epoch 48/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2873The average loss for epoch 47 is    0.12
# 78/78 [==============================] - 14s 176ms/step - loss: 0.1291 - categorical_accuracy: 0.2821
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1221 - categorical_accuracy: 0.2870
# Epoch 49/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1257 - categorical_accuracy: 0.2886The average loss for epoch 48 is    0.13
# 78/78 [==============================] - 14s 183ms/step - loss: 0.2313 - categorical_accuracy: 0.5705
# 652/652 [==============================] - 99s 151ms/step - loss: 0.1263 - categorical_accuracy: 0.2893
# Epoch 50/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2922The average loss for epoch 49 is    0.12
# 78/78 [==============================] - 19s 245ms/step - loss: 0.3383 - categorical_accuracy: 0.5625
# 652/652 [==============================] - 102s 157ms/step - loss: 0.1220 - categorical_accuracy: 0.2920
# Epoch 51/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1249 - categorical_accuracy: 0.2978The average loss for epoch 50 is    0.13
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0956 - categorical_accuracy: 0.2804
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1254 - categorical_accuracy: 0.2989
# Epoch 52/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1250 - categorical_accuracy: 0.3011The average loss for epoch 51 is    0.13
# 78/78 [==============================] - 13s 166ms/step - loss: 0.1373 - categorical_accuracy: 0.4535
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1254 - categorical_accuracy: 0.3021
# Epoch 53/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.2967The average loss for epoch 52 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1212 - categorical_accuracy: 0.2964
# Epoch 54/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.2922The average loss for epoch 53 is    0.12
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 99s 151ms/step - loss: 0.1212 - categorical_accuracy: 0.2918
# Epoch 55/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1221 - categorical_accuracy: 0.2942The average loss for epoch 54 is    0.12
# 78/78 [==============================] - 13s 169ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1219 - categorical_accuracy: 0.2939
# Epoch 56/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1204 - categorical_accuracy: 0.2978The average loss for epoch 55 is    0.12
# 78/78 [==============================] - 15s 198ms/step - loss: 0.2053 - categorical_accuracy: 0.3926
# 652/652 [==============================] - 102s 157ms/step - loss: 0.1202 - categorical_accuracy: 0.2975
# Epoch 57/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1250 - categorical_accuracy: 0.2959The average loss for epoch 56 is    0.13
# 78/78 [==============================] - 13s 170ms/step - loss: 0.1496 - categorical_accuracy: 0.4631
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1256 - categorical_accuracy: 0.2968
# Epoch 58/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.2896The average loss for epoch 57 is    0.12
# 78/78 [==============================] - 20s 257ms/step - loss: 0.3687 - categorical_accuracy: 0.6987
# 652/652 [==============================] - 102s 156ms/step - loss: 0.1213 - categorical_accuracy: 0.2893
# Epoch 59/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1224 - categorical_accuracy: 0.2894The average loss for epoch 58 is    0.12
# 78/78 [==============================] - 14s 179ms/step - loss: 0.1436 - categorical_accuracy: 0.3189
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1223 - categorical_accuracy: 0.2891
# Epoch 60/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1242 - categorical_accuracy: 0.2957The average loss for epoch 59 is    0.12
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0724 - categorical_accuracy: 0.3205
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1248 - categorical_accuracy: 0.2968
# Epoch 61/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1203 - categorical_accuracy: 0.2963The average loss for epoch 60 is    0.12
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1202 - categorical_accuracy: 0.2958
# Epoch 62/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2934The average loss for epoch 61 is    0.12
# 78/78 [==============================] - 12s 159ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1214 - categorical_accuracy: 0.2929
# Epoch 63/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1213 - categorical_accuracy: 0.2930The average loss for epoch 62 is    0.12
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1211 - categorical_accuracy: 0.2928
# Epoch 64/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.2874The average loss for epoch 63 is    0.12
# 78/78 [==============================] - 16s 208ms/step - loss: 0.2836 - categorical_accuracy: 0.5000
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1230 - categorical_accuracy: 0.2874
# Epoch 65/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.3049The average loss for epoch 64 is    0.12
# 78/78 [==============================] - 13s 160ms/step - loss: 0.0870 - categorical_accuracy: 0.3397
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1226 - categorical_accuracy: 0.3058
# Epoch 66/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1243 - categorical_accuracy: 0.2894The average loss for epoch 65 is    0.12
# 78/78 [==============================] - 19s 243ms/step - loss: 0.3303 - categorical_accuracy: 0.7244
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1246 - categorical_accuracy: 0.2901
# Epoch 67/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1226 - categorical_accuracy: 0.2897The average loss for epoch 66 is    0.12
# 78/78 [==============================] - 15s 198ms/step - loss: 0.2217 - categorical_accuracy: 0.4167
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1224 - categorical_accuracy: 0.2893
# Epoch 68/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1243 - categorical_accuracy: 0.2992The average loss for epoch 67 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0116 - categorical_accuracy: 0.2083
# 652/652 [==============================] - 92s 141ms/step - loss: 0.1245 - categorical_accuracy: 0.2997
# Epoch 69/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1204 - categorical_accuracy: 0.3011The average loss for epoch 68 is    0.12
# 78/78 [==============================] - 12s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1939
# 652/652 [==============================] - 93s 143ms/step - loss: 0.1202 - categorical_accuracy: 0.3008
# Epoch 70/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1224 - categorical_accuracy: 0.2986The average loss for epoch 69 is    0.12
# 78/78 [==============================] - 12s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1939
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1222 - categorical_accuracy: 0.2983
# Epoch 71/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2945The average loss for epoch 70 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1939
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1214 - categorical_accuracy: 0.2945
# Epoch 72/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.2930The average loss for epoch 71 is    0.12
# 78/78 [==============================] - 18s 229ms/step - loss: 0.3604 - categorical_accuracy: 0.6154
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1218 - categorical_accuracy: 0.2928
# Epoch 73/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1235 - categorical_accuracy: 0.2995The average loss for epoch 72 is    0.12
# 78/78 [==============================] - 13s 165ms/step - loss: 0.1054 - categorical_accuracy: 0.2580
# 652/652 [==============================] - 96s 146ms/step - loss: 0.1238 - categorical_accuracy: 0.3000
# Epoch 74/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1249 - categorical_accuracy: 0.3013The average loss for epoch 73 is    0.13
# 78/78 [==============================] - 17s 220ms/step - loss: 0.2655 - categorical_accuracy: 0.6218
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1254 - categorical_accuracy: 0.3023
# Epoch 75/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1223 - categorical_accuracy: 0.2942The average loss for epoch 74 is    0.12
# 78/78 [==============================] - 15s 189ms/step - loss: 0.2258 - categorical_accuracy: 0.4824
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1221 - categorical_accuracy: 0.2937
# Epoch 76/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1202 - categorical_accuracy: 0.3030The average loss for epoch 75 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1923
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1200 - categorical_accuracy: 0.3027
# Epoch 77/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1218 - categorical_accuracy: 0.2957The average loss for epoch 76 is    0.12
# 78/78 [==============================] - 13s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1923
# 652/652 [==============================] - 94s 145ms/step - loss: 0.1216 - categorical_accuracy: 0.2952
# Epoch 78/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2972The average loss for epoch 77 is    0.12
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1923
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1223 - categorical_accuracy: 0.2968
# Epoch 79/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2955The average loss for epoch 78 is    0.12
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1923
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1214 - categorical_accuracy: 0.2954
# Epoch 80/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2990The average loss for epoch 79 is    0.12
# 78/78 [==============================] - 17s 220ms/step - loss: 0.3606 - categorical_accuracy: 0.7196
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1220 - categorical_accuracy: 0.2985
# Epoch 81/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1227 - categorical_accuracy: 0.2924The average loss for epoch 80 is    0.12
# 78/78 [==============================] - 15s 192ms/step - loss: 0.1687 - categorical_accuracy: 0.3750
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1225 - categorical_accuracy: 0.2920
# Epoch 82/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1240 - categorical_accuracy: 0.2993The average loss for epoch 81 is    0.12
# 78/78 [==============================] - 16s 205ms/step - loss: 0.1881 - categorical_accuracy: 0.5096
# 652/652 [==============================] - 101s 155ms/step - loss: 0.1245 - categorical_accuracy: 0.3002
# Epoch 83/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1223 - categorical_accuracy: 0.2901The average loss for epoch 82 is    0.12
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2150 - categorical_accuracy: 0.5080
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1221 - categorical_accuracy: 0.2899
# Epoch 84/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1229 - categorical_accuracy: 0.2922The average loss for epoch 83 is    0.12
# 78/78 [==============================] - 12s 159ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1227 - categorical_accuracy: 0.2918
# Epoch 85/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1209 - categorical_accuracy: 0.2986The average loss for epoch 84 is    0.12
# 78/78 [==============================] - 13s 166ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1207 - categorical_accuracy: 0.2981
# Epoch 86/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1213 - categorical_accuracy: 0.2980The average loss for epoch 85 is    0.12
# 78/78 [==============================] - 13s 167ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 99s 153ms/step - loss: 0.1211 - categorical_accuracy: 0.2977
# Epoch 87/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2940The average loss for epoch 86 is    0.12
# 78/78 [==============================] - 13s 171ms/step - loss: 0.0282 - categorical_accuracy: 0.2115
# 652/652 [==============================] - 100s 154ms/step - loss: 0.1214 - categorical_accuracy: 0.2939
# Epoch 88/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1252 - categorical_accuracy: 0.3032The average loss for epoch 87 is    0.13
# 78/78 [==============================] - 16s 209ms/step - loss: 0.3089 - categorical_accuracy: 0.6747
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1255 - categorical_accuracy: 0.3039
# Epoch 89/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1212 - categorical_accuracy: 0.2917The average loss for epoch 88 is    0.12
# 78/78 [==============================] - 16s 210ms/step - loss: 0.2449 - categorical_accuracy: 0.4696
# 652/652 [==============================] - 100s 154ms/step - loss: 0.1210 - categorical_accuracy: 0.2912
# Epoch 90/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1258 - categorical_accuracy: 0.3022The average loss for epoch 89 is    0.13
# 78/78 [==============================] - 14s 179ms/step - loss: 0.1116 - categorical_accuracy: 0.3878
# 652/652 [==============================] - 95s 145ms/step - loss: 0.1264 - categorical_accuracy: 0.3031
# Epoch 91/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1203 - categorical_accuracy: 0.3017The average loss for epoch 90 is    0.12
# 78/78 [==============================] - 14s 179ms/step - loss: 0.1996 - categorical_accuracy: 0.5224
# 652/652 [==============================] - 97s 149ms/step - loss: 0.1201 - categorical_accuracy: 0.3012
# Epoch 92/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1218 - categorical_accuracy: 0.2932The average loss for epoch 91 is    0.12
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1217 - categorical_accuracy: 0.2931
# Epoch 93/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1227 - categorical_accuracy: 0.2936The average loss for epoch 92 is    0.12
# 78/78 [==============================] - 12s 158ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 96s 147ms/step - loss: 0.1225 - categorical_accuracy: 0.2931
# Epoch 94/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1242 - categorical_accuracy: 0.2922The average loss for epoch 93 is    0.12
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1240 - categorical_accuracy: 0.2922
# Epoch 95/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1221 - categorical_accuracy: 0.2944The average loss for epoch 94 is    0.12
# 78/78 [==============================] - 14s 180ms/step - loss: 0.1201 - categorical_accuracy: 0.2837
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1220 - categorical_accuracy: 0.2939
# Epoch 96/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1233 - categorical_accuracy: 0.3030The average loss for epoch 95 is    0.12
# 78/78 [==============================] - 15s 187ms/step - loss: 0.2345 - categorical_accuracy: 0.5769
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1238 - categorical_accuracy: 0.3041
# Epoch 97/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1227 - categorical_accuracy: 0.2957The average loss for epoch 96 is    0.12
# 78/78 [==============================] - 19s 246ms/step - loss: 0.3315 - categorical_accuracy: 0.5609
# 652/652 [==============================] - 103s 158ms/step - loss: 0.1225 - categorical_accuracy: 0.2952
# Epoch 98/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1247 - categorical_accuracy: 0.2957The average loss for epoch 97 is    0.13
# 78/78 [==============================] - 13s 171ms/step - loss: 0.0927 - categorical_accuracy: 0.2885
# 652/652 [==============================] - 99s 153ms/step - loss: 0.1251 - categorical_accuracy: 0.2968
# Epoch 99/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1245 - categorical_accuracy: 0.2982The average loss for epoch 98 is    0.12
# 78/78 [==============================] - 14s 181ms/step - loss: 0.1424 - categorical_accuracy: 0.4455
# 652/652 [==============================] - 103s 158ms/step - loss: 0.1250 - categorical_accuracy: 0.2993
# Epoch 100/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2997The average loss for epoch 99 is    0.12
# 78/78 [==============================] - 12s 157ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1223 - categorical_accuracy: 0.2993
# Epoch 101/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.2957The average loss for epoch 100 is    0.12
# 78/78 [==============================] - 12s 159ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 96s 148ms/step - loss: 0.1229 - categorical_accuracy: 0.2952
# Epoch 102/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1206 - categorical_accuracy: 0.2932The average loss for epoch 101 is    0.12
# 78/78 [==============================] - 12s 156ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 94s 144ms/step - loss: 0.1204 - categorical_accuracy: 0.2931
# Epoch 103/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1209 - categorical_accuracy: 0.2901The average loss for epoch 102 is    0.12
# 78/78 [==============================] - 15s 194ms/step - loss: 0.1996 - categorical_accuracy: 0.3846
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1207 - categorical_accuracy: 0.2897
# Epoch 104/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1251 - categorical_accuracy: 0.2955The average loss for epoch 103 is    0.13
# 78/78 [==============================] - 14s 173ms/step - loss: 0.1576 - categorical_accuracy: 0.4551
# 652/652 [==============================] - 95s 146ms/step - loss: 0.1256 - categorical_accuracy: 0.2966
# Epoch 105/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1208 - categorical_accuracy: 0.2986The average loss for epoch 104 is    0.12
# 78/78 [==============================] - 20s 252ms/step - loss: 0.3722 - categorical_accuracy: 0.7035
# 652/652 [==============================] - 102s 157ms/step - loss: 0.1206 - categorical_accuracy: 0.2983
# Epoch 106/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2911The average loss for epoch 105 is    0.12
# 78/78 [==============================] - 14s 180ms/step - loss: 0.1410 - categorical_accuracy: 0.3061
# 652/652 [==============================] - 97s 148ms/step - loss: 0.1224 - categorical_accuracy: 0.2910
# Epoch 107/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1250 - categorical_accuracy: 0.3003The average loss for epoch 106 is    0.13
# 78/78 [==============================] - 14s 174ms/step - loss: 0.0794 - categorical_accuracy: 0.3189
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1255 - categorical_accuracy: 0.3014
# Epoch 108/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1206 - categorical_accuracy: 0.2947The average loss for epoch 107 is    0.12
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1204 - categorical_accuracy: 0.2943
# Epoch 109/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1204 - categorical_accuracy: 0.2972The average loss for epoch 108 is    0.12
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1202 - categorical_accuracy: 0.2968
# Epoch 110/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1229 - categorical_accuracy: 0.2963The average loss for epoch 109 is    0.12
# 78/78 [==============================] - 13s 166ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 100s 154ms/step - loss: 0.1227 - categorical_accuracy: 0.2962
# Epoch 111/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1218 - categorical_accuracy: 0.3015The average loss for epoch 110 is    0.12
# 78/78 [==============================] - 17s 222ms/step - loss: 0.2757 - categorical_accuracy: 0.5048
# 652/652 [==============================] - 103s 158ms/step - loss: 0.1216 - categorical_accuracy: 0.3012
# Epoch 112/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1242 - categorical_accuracy: 0.2949The average loss for epoch 111 is    0.12
# 78/78 [==============================] - 14s 175ms/step - loss: 0.0873 - categorical_accuracy: 0.3349
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1247 - categorical_accuracy: 0.2960
# Epoch 113/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1219 - categorical_accuracy: 0.2924The average loss for epoch 112 is    0.12
# 78/78 [==============================] - 21s 264ms/step - loss: 0.3349 - categorical_accuracy: 0.7324
# 652/652 [==============================] - 109s 167ms/step - loss: 0.1224 - categorical_accuracy: 0.2933
# Epoch 114/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2944The average loss for epoch 113 is    0.12
# 78/78 [==============================] - 17s 222ms/step - loss: 0.2130 - categorical_accuracy: 0.4151
# 652/652 [==============================] - 107s 164ms/step - loss: 0.1220 - categorical_accuracy: 0.2941
# Epoch 115/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.2970The average loss for epoch 114 is    0.12
# 78/78 [==============================] - 13s 167ms/step - loss: 0.0145 - categorical_accuracy: 0.1939
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1233 - categorical_accuracy: 0.2975
# Epoch 116/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1216 - categorical_accuracy: 0.2922The average loss for epoch 115 is    0.12
# 78/78 [==============================] - 13s 168ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1214 - categorical_accuracy: 0.2918
# Epoch 117/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1222 - categorical_accuracy: 0.2970The average loss for epoch 116 is    0.12
# 78/78 [==============================] - 13s 170ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 99s 152ms/step - loss: 0.1220 - categorical_accuracy: 0.2966
# Epoch 118/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1223 - categorical_accuracy: 0.2970The average loss for epoch 117 is    0.12
# 78/78 [==============================] - 13s 161ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 98s 151ms/step - loss: 0.1221 - categorical_accuracy: 0.2970
# Epoch 119/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1217 - categorical_accuracy: 0.2947The average loss for epoch 118 is    0.12
# 78/78 [==============================] - 18s 234ms/step - loss: 0.3573 - categorical_accuracy: 0.6170
# 652/652 [==============================] - 105s 161ms/step - loss: 0.1215 - categorical_accuracy: 0.2943
# Epoch 120/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1241 - categorical_accuracy: 0.3038The average loss for epoch 119 is    0.12
# 78/78 [==============================] - 14s 176ms/step - loss: 0.1082 - categorical_accuracy: 0.2468
# 652/652 [==============================] - 100s 154ms/step - loss: 0.1245 - categorical_accuracy: 0.3043
# Epoch 121/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1237 - categorical_accuracy: 0.2997The average loss for epoch 120 is    0.12
# 78/78 [==============================] - 18s 234ms/step - loss: 0.2660 - categorical_accuracy: 0.6330
# 652/652 [==============================] - 106s 162ms/step - loss: 0.1242 - categorical_accuracy: 0.3006
# Epoch 122/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1235 - categorical_accuracy: 0.2997The average loss for epoch 121 is    0.12
# 78/78 [==============================] - 16s 202ms/step - loss: 0.2249 - categorical_accuracy: 0.4968
# 652/652 [==============================] - 102s 156ms/step - loss: 0.1233 - categorical_accuracy: 0.2995
# Epoch 123/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.2967The average loss for epoch 122 is    0.12
# 78/78 [==============================] - 13s 164ms/step - loss: 4.8830e-04 - categorical_accuracy: 0.1923
# 652/652 [==============================] - 99s 153ms/step - loss: 0.1218 - categorical_accuracy: 0.2962
# Epoch 124/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.2865The average loss for epoch 123 is    0.12
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1907
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1223 - categorical_accuracy: 0.2860
# Epoch 125/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1205 - categorical_accuracy: 0.2963The average loss for epoch 124 is    0.12
# 78/78 [==============================] - 13s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 98s 150ms/step - loss: 0.1203 - categorical_accuracy: 0.2958
# Epoch 126/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1227 - categorical_accuracy: 0.2922The average loss for epoch 125 is    0.12
# 78/78 [==============================] - 13s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1225 - categorical_accuracy: 0.2918
# Epoch 127/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1223 - categorical_accuracy: 0.2936The average loss for epoch 126 is    0.12
# 78/78 [==============================] - 18s 225ms/step - loss: 0.3580 - categorical_accuracy: 0.7436
# 652/652 [==============================] - 102s 157ms/step - loss: 0.1221 - categorical_accuracy: 0.2933
# Epoch 128/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1247 - categorical_accuracy: 0.2986The average loss for epoch 127 is    0.12
# 78/78 [==============================] - 15s 188ms/step - loss: 0.1657 - categorical_accuracy: 0.3462
# 652/652 [==============================] - 100s 153ms/step - loss: 0.1245 - categorical_accuracy: 0.2981
# Epoch 129/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1251 - categorical_accuracy: 0.2990The average loss for epoch 128 is    0.13
# 78/78 [==============================] - 16s 203ms/step - loss: 0.1917 - categorical_accuracy: 0.5128
# 652/652 [==============================] - 100s 154ms/step - loss: 0.1255 - categorical_accuracy: 0.3000
# Epoch 130/130
# 651/652 [============================>.] - ETA: 0s - loss: 0.1217 - categorical_accuracy: 0.2986The average loss for epoch 129 is    0.12
# 78/78 [==============================] - 15s 187ms/step - loss: 0.2144 - categorical_accuracy: 0.5064
# 652/652 [==============================] - 99s 153ms/step - loss: 0.1215 - categorical_accuracy: 0.2981
