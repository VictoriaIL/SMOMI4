# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/СМОМИ/Лаба 4")
# !ls
# Out:
# '4lab_bright(0.5).ipynb'   lab_flip.ipynb       logs
#  images			   lab_rotate40.ipynb   modelB.h5

# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 47kB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 43.4MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 59.0MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (47.1.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
import math
from tensorflow.python import keras as keras
from keras.models import load_model
from numpy import asarray
import PIL
from PIL import Image
import random


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624



def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize_images(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], example['image/class/label']


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .repeat()\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def create_aug_dataset(filenames, batch_size):
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .map(augment)\
        .shuffle(buffer_size=5 * batch_size)\
        .repeat()\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def augment(image,label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.random_brightness(image, 0.5, seed=None)
    image = tf.image.random_contrast(image, 0.4, 1.4, seed=None)
    return image,label
 

class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })


def build_model():
    model = keras.models.load_model('modelB.h5')
    model.trainable = True
    return model



def main():
    train_path = './images/train*'
    test_path = './images/test*'
    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)


    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=1e-11, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=100,
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1514: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# WARNING:tensorflow:From <ipython-input-4-bbb7b0e8b9fb>:104: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0185 - categorical_accuracy: 0.2940The average loss for epoch 0 is    0.02
# 78/78 [==============================] - 20s 262ms/step - loss: 0.0798 - categorical_accuracy: 0.2516
# 652/652 [==============================] - 123s 189ms/step - loss: 0.0185 - categorical_accuracy: 0.2939
# Epoch 2/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0285 - categorical_accuracy: 0.3641The average loss for epoch 1 is    0.03
# 78/78 [==============================] - 16s 211ms/step - loss: 5.0805e-04 - categorical_accuracy: 0.1474
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0285 - categorical_accuracy: 0.3641
# Epoch 3/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0178 - categorical_accuracy: 0.2988The average loss for epoch 2 is    0.02
# 78/78 [==============================] - 20s 256ms/step - loss: 0.1812 - categorical_accuracy: 0.4968
# 652/652 [==============================] - 110s 169ms/step - loss: 0.0178 - categorical_accuracy: 0.2985
# Epoch 4/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0183 - categorical_accuracy: 0.3041The average loss for epoch 3 is    0.02
# 78/78 [==============================] - 16s 208ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1458
# 652/652 [==============================] - 105s 161ms/step - loss: 0.0182 - categorical_accuracy: 0.3043
# Epoch 5/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0177 - categorical_accuracy: 0.2940The average loss for epoch 4 is    0.02
# 78/78 [==============================] - 18s 225ms/step - loss: 0.0043 - categorical_accuracy: 0.1522
# 652/652 [==============================] - 106s 163ms/step - loss: 0.0177 - categorical_accuracy: 0.2939
# Epoch 6/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0298 - categorical_accuracy: 0.3758The average loss for epoch 5 is    0.03
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0089 - categorical_accuracy: 0.1699
# 652/652 [==============================] - 114s 175ms/step - loss: 0.0298 - categorical_accuracy: 0.3758
# Epoch 7/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0186 - categorical_accuracy: 0.3065The average loss for epoch 6 is    0.02
# 78/78 [==============================] - 19s 240ms/step - loss: 0.1407 - categorical_accuracy: 0.3686
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0186 - categorical_accuracy: 0.3066
# Epoch 8/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0195 - categorical_accuracy: 0.3147The average loss for epoch 7 is    0.02
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1442
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0195 - categorical_accuracy: 0.3142
# Epoch 9/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0184 - categorical_accuracy: 0.2986The average loss for epoch 8 is    0.02
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1442
# 652/652 [==============================] - 107s 163ms/step - loss: 0.0183 - categorical_accuracy: 0.2981
# Epoch 10/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0267 - categorical_accuracy: 0.3660The average loss for epoch 9 is    0.03
# 78/78 [==============================] - 17s 221ms/step - loss: 0.0711 - categorical_accuracy: 0.2965
# 652/652 [==============================] - 111s 171ms/step - loss: 0.0268 - categorical_accuracy: 0.3669
# Epoch 11/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0176 - categorical_accuracy: 0.3057The average loss for epoch 10 is    0.02
# 78/78 [==============================] - 17s 222ms/step - loss: 0.0677 - categorical_accuracy: 0.2292
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0176 - categorical_accuracy: 0.3058
# Epoch 12/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0218 - categorical_accuracy: 0.3324The average loss for epoch 11 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1410
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0217 - categorical_accuracy: 0.3322
# Epoch 13/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0179 - categorical_accuracy: 0.3041The average loss for epoch 12 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1394
# 652/652 [==============================] - 105s 161ms/step - loss: 0.0178 - categorical_accuracy: 0.3039
# Epoch 14/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0238 - categorical_accuracy: 0.3447The average loss for epoch 13 is    0.02
# 78/78 [==============================] - 17s 223ms/step - loss: 0.1665 - categorical_accuracy: 0.3958
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0240 - categorical_accuracy: 0.3457
# Epoch 15/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0176 - categorical_accuracy: 0.3072The average loss for epoch 14 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0022 - categorical_accuracy: 0.1426
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0175 - categorical_accuracy: 0.3069
# Epoch 16/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0232 - categorical_accuracy: 0.3523The average loss for epoch 15 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1378
# 652/652 [==============================] - 109s 166ms/step - loss: 0.0231 - categorical_accuracy: 0.3522
# Epoch 17/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0175 - categorical_accuracy: 0.3055The average loss for epoch 16 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1394
# 652/652 [==============================] - 105s 162ms/step - loss: 0.0175 - categorical_accuracy: 0.3052
# Epoch 18/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.3377The average loss for epoch 17 is    0.02
# 78/78 [==============================] - 20s 250ms/step - loss: 0.2485 - categorical_accuracy: 0.5176
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0218 - categorical_accuracy: 0.3388
# Epoch 19/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0167 - categorical_accuracy: 0.3109The average loss for epoch 18 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1394
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0167 - categorical_accuracy: 0.3108
# Epoch 20/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0235 - categorical_accuracy: 0.3485The average loss for epoch 19 is    0.02
# 78/78 [==============================] - 17s 219ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1394
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0234 - categorical_accuracy: 0.3485
# Epoch 21/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0168 - categorical_accuracy: 0.3074The average loss for epoch 20 is    0.02
# 78/78 [==============================] - 17s 221ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1426
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0168 - categorical_accuracy: 0.3071
# Epoch 22/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 0.3197The average loss for epoch 21 is    0.02
# 78/78 [==============================] - 21s 273ms/step - loss: 0.3088 - categorical_accuracy: 0.6731
# 652/652 [==============================] - 115s 176ms/step - loss: 0.0189 - categorical_accuracy: 0.3207
# Epoch 23/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0165 - categorical_accuracy: 0.3095The average loss for epoch 22 is    0.02
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1410
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0165 - categorical_accuracy: 0.3094
# Epoch 24/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0218 - categorical_accuracy: 0.3508The average loss for epoch 23 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0120 - categorical_accuracy: 0.1699
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0219 - categorical_accuracy: 0.3512
# Epoch 25/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0168 - categorical_accuracy: 0.3070The average loss for epoch 24 is    0.02
# 78/78 [==============================] - 17s 214ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1426
# 652/652 [==============================] - 105s 161ms/step - loss: 0.0168 - categorical_accuracy: 0.3066
# Epoch 26/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0167 - categorical_accuracy: 0.3105The average loss for epoch 25 is    0.02
# 78/78 [==============================] - 23s 301ms/step - loss: 0.3633 - categorical_accuracy: 0.7468
# 652/652 [==============================] - 114s 175ms/step - loss: 0.0167 - categorical_accuracy: 0.3106
# Epoch 27/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0169 - categorical_accuracy: 0.3153The average loss for epoch 26 is    0.02
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1442
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0169 - categorical_accuracy: 0.3148
# Epoch 28/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0195 - categorical_accuracy: 0.3366The average loss for epoch 27 is    0.02
# 78/78 [==============================] - 18s 224ms/step - loss: 0.0827 - categorical_accuracy: 0.2949
# 652/652 [==============================] - 110s 168ms/step - loss: 0.0196 - categorical_accuracy: 0.3376
# Epoch 29/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 0.3180The average loss for epoch 28 is    0.02
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1458
# 652/652 [==============================] - 106s 163ms/step - loss: 0.0166 - categorical_accuracy: 0.3181
# Epoch 30/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 0.3161The average loss for epoch 29 is    0.02
# 78/78 [==============================] - 23s 299ms/step - loss: 0.3410 - categorical_accuracy: 0.6603
# 652/652 [==============================] - 114s 175ms/step - loss: 0.0166 - categorical_accuracy: 0.3156
# Epoch 31/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0176 - categorical_accuracy: 0.3312The average loss for epoch 30 is    0.02
# 78/78 [==============================] - 17s 219ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1458
# 652/652 [==============================] - 107s 163ms/step - loss: 0.0176 - categorical_accuracy: 0.3311
# Epoch 32/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0174 - categorical_accuracy: 0.3232The average loss for epoch 31 is    0.02
# 78/78 [==============================] - 18s 230ms/step - loss: 0.1749 - categorical_accuracy: 0.3942
# 652/652 [==============================] - 110s 168ms/step - loss: 0.0175 - categorical_accuracy: 0.3242
# Epoch 33/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0158 - categorical_accuracy: 0.3185The average loss for epoch 32 is    0.02
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1474
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0158 - categorical_accuracy: 0.3183
# Epoch 34/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0162 - categorical_accuracy: 0.3216The average loss for epoch 33 is    0.02
# 78/78 [==============================] - 22s 281ms/step - loss: 0.2411 - categorical_accuracy: 0.5721
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0162 - categorical_accuracy: 0.3217
# Epoch 35/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0191 - categorical_accuracy: 0.3504The average loss for epoch 34 is    0.02
# 78/78 [==============================] - 17s 219ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1474
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0191 - categorical_accuracy: 0.3503
# Epoch 36/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 0.3241The average loss for epoch 35 is    0.02
# 78/78 [==============================] - 20s 252ms/step - loss: 0.2306 - categorical_accuracy: 0.4647
# 652/652 [==============================] - 109s 168ms/step - loss: 0.0166 - categorical_accuracy: 0.3238
# Epoch 37/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0167 - categorical_accuracy: 0.3224The average loss for epoch 36 is    0.02
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1474
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0167 - categorical_accuracy: 0.3223
# Epoch 38/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0161 - categorical_accuracy: 0.3182The average loss for epoch 37 is    0.02
# 78/78 [==============================] - 20s 257ms/step - loss: 0.1703 - categorical_accuracy: 0.4391
# 652/652 [==============================] - 109s 168ms/step - loss: 0.0160 - categorical_accuracy: 0.3181
# Epoch 39/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0211 - categorical_accuracy: 0.3689The average loss for epoch 38 is    0.02
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1490
# 652/652 [==============================] - 110s 169ms/step - loss: 0.0211 - categorical_accuracy: 0.3687
# Epoch 40/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0158 - categorical_accuracy: 0.3272The average loss for epoch 39 is    0.02
# 78/78 [==============================] - 20s 252ms/step - loss: 0.2116 - categorical_accuracy: 0.4840
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0158 - categorical_accuracy: 0.3269
# Epoch 41/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0165 - categorical_accuracy: 0.3247The average loss for epoch 40 is    0.02
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1538
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0165 - categorical_accuracy: 0.3242
# Epoch 42/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0161 - categorical_accuracy: 0.3257The average loss for epoch 41 is    0.02
# 78/78 [==============================] - 18s 228ms/step - loss: 0.1091 - categorical_accuracy: 0.3061
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0161 - categorical_accuracy: 0.3252
# Epoch 43/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0241 - categorical_accuracy: 0.3800The average loss for epoch 42 is    0.02
# 78/78 [==============================] - 17s 212ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1538
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0241 - categorical_accuracy: 0.3798
# Epoch 44/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0157 - categorical_accuracy: 0.3245The average loss for epoch 43 is    0.02
# 78/78 [==============================] - 21s 271ms/step - loss: 0.1887 - categorical_accuracy: 0.4920
# 652/652 [==============================] - 114s 174ms/step - loss: 0.0157 - categorical_accuracy: 0.3242
# Epoch 45/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0163 - categorical_accuracy: 0.3293The average loss for epoch 44 is    0.02
# 78/78 [==============================] - 17s 223ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1554
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0163 - categorical_accuracy: 0.3290
# Epoch 46/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0159 - categorical_accuracy: 0.3260The average loss for epoch 45 is    0.02
# 78/78 [==============================] - 18s 227ms/step - loss: 0.0349 - categorical_accuracy: 0.1891
# 652/652 [==============================] - 110s 169ms/step - loss: 0.0159 - categorical_accuracy: 0.3257
# Epoch 47/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0252 - categorical_accuracy: 0.3977The average loss for epoch 46 is    0.03
# 78/78 [==============================] - 17s 218ms/step - loss: 0.0025 - categorical_accuracy: 0.1651
# 652/652 [==============================] - 118s 180ms/step - loss: 0.0253 - categorical_accuracy: 0.3980
# Epoch 48/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0156 - categorical_accuracy: 0.3337The average loss for epoch 47 is    0.02
# 78/78 [==============================] - 20s 254ms/step - loss: 0.1681 - categorical_accuracy: 0.4119
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0156 - categorical_accuracy: 0.3338
# Epoch 49/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 0.3399The average loss for epoch 48 is    0.02
# 78/78 [==============================] - 17s 218ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1603
# 652/652 [==============================] - 108s 165ms/step - loss: 0.0166 - categorical_accuracy: 0.3395
# Epoch 50/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0157 - categorical_accuracy: 0.3293The average loss for epoch 49 is    0.02
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1603
# 652/652 [==============================] - 106s 163ms/step - loss: 0.0157 - categorical_accuracy: 0.3290
# Epoch 51/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0247 - categorical_accuracy: 0.4003The average loss for epoch 50 is    0.02
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0381 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 114s 175ms/step - loss: 0.0248 - categorical_accuracy: 0.4013
# Epoch 52/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0154 - categorical_accuracy: 0.3328The average loss for epoch 51 is    0.02
# 78/78 [==============================] - 18s 226ms/step - loss: 0.1003 - categorical_accuracy: 0.2933
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0154 - categorical_accuracy: 0.3322
# Epoch 53/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0184 - categorical_accuracy: 0.3591The average loss for epoch 52 is    0.02
# 78/78 [==============================] - 17s 214ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1587
# 652/652 [==============================] - 108s 165ms/step - loss: 0.0183 - categorical_accuracy: 0.3587
# Epoch 54/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0160 - categorical_accuracy: 0.3322The average loss for epoch 53 is    0.02
# 78/78 [==============================] - 17s 213ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1587
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0160 - categorical_accuracy: 0.3321
# Epoch 55/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0219 - categorical_accuracy: 0.3834The average loss for epoch 54 is    0.02
# 78/78 [==============================] - 18s 230ms/step - loss: 0.1246 - categorical_accuracy: 0.3750
# 652/652 [==============================] - 114s 174ms/step - loss: 0.0220 - categorical_accuracy: 0.3844
# Epoch 56/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3383The average loss for epoch 55 is    0.02
# 78/78 [==============================] - 17s 222ms/step - loss: 0.0314 - categorical_accuracy: 0.1651
# 652/652 [==============================] - 108s 165ms/step - loss: 0.0152 - categorical_accuracy: 0.3380
# Epoch 57/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0203 - categorical_accuracy: 0.3806The average loss for epoch 56 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1635
# 652/652 [==============================] - 110s 168ms/step - loss: 0.0203 - categorical_accuracy: 0.3800
# Epoch 58/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0156 - categorical_accuracy: 0.3481The average loss for epoch 57 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1651
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0156 - categorical_accuracy: 0.3480
# Epoch 59/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0205 - categorical_accuracy: 0.3717The average loss for epoch 58 is    0.02
# 78/78 [==============================] - 18s 235ms/step - loss: 0.2250 - categorical_accuracy: 0.4535
# 652/652 [==============================] - 115s 176ms/step - loss: 0.0206 - categorical_accuracy: 0.3727
# Epoch 60/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0155 - categorical_accuracy: 0.3441The average loss for epoch 59 is    0.02
# 78/78 [==============================] - 17s 218ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1651
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0155 - categorical_accuracy: 0.3436
# Epoch 61/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0201 - categorical_accuracy: 0.3932The average loss for epoch 60 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1667
# 652/652 [==============================] - 110s 169ms/step - loss: 0.0201 - categorical_accuracy: 0.3930
# Epoch 62/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0155 - categorical_accuracy: 0.3445The average loss for epoch 61 is    0.02
# 78/78 [==============================] - 17s 214ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1667
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0155 - categorical_accuracy: 0.3443
# Epoch 63/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0173 - categorical_accuracy: 0.3656The average loss for epoch 62 is    0.02
# 78/78 [==============================] - 20s 262ms/step - loss: 0.2827 - categorical_accuracy: 0.6026
# 652/652 [==============================] - 114s 174ms/step - loss: 0.0174 - categorical_accuracy: 0.3666
# Epoch 64/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0157 - categorical_accuracy: 0.3516The average loss for epoch 63 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1683
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0157 - categorical_accuracy: 0.3510
# Epoch 65/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0208 - categorical_accuracy: 0.3877The average loss for epoch 64 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0031 - categorical_accuracy: 0.1827
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0208 - categorical_accuracy: 0.3877
# Epoch 66/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3489The average loss for epoch 65 is    0.02
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1715
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0152 - categorical_accuracy: 0.3487
# Epoch 67/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0159 - categorical_accuracy: 0.3600The average loss for epoch 66 is    0.02
# 78/78 [==============================] - 23s 289ms/step - loss: 0.3531 - categorical_accuracy: 0.7099
# 652/652 [==============================] - 115s 177ms/step - loss: 0.0159 - categorical_accuracy: 0.3604
# Epoch 68/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0154 - categorical_accuracy: 0.3581The average loss for epoch 67 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1715
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0154 - categorical_accuracy: 0.3577
# Epoch 69/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0198 - categorical_accuracy: 0.3875The average loss for epoch 68 is    0.02
# 78/78 [==============================] - 17s 222ms/step - loss: 0.0454 - categorical_accuracy: 0.2804
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0199 - categorical_accuracy: 0.3884
# Epoch 70/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0153 - categorical_accuracy: 0.3529The average loss for epoch 69 is    0.02
# 78/78 [==============================] - 16s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1731
# 652/652 [==============================] - 107s 164ms/step - loss: 0.0153 - categorical_accuracy: 0.3528
# Epoch 71/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0145 - categorical_accuracy: 0.3594The average loss for epoch 70 is    0.01
# 78/78 [==============================] - 24s 301ms/step - loss: 0.3738 - categorical_accuracy: 0.6811
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0145 - categorical_accuracy: 0.3595
# Epoch 72/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0151 - categorical_accuracy: 0.3627The average loss for epoch 71 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1731
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0150 - categorical_accuracy: 0.3625
# Epoch 73/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0171 - categorical_accuracy: 0.3690The average loss for epoch 72 is    0.02
# 78/78 [==============================] - 18s 233ms/step - loss: 0.1388 - categorical_accuracy: 0.3894
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0172 - categorical_accuracy: 0.3700
# Epoch 74/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0151 - categorical_accuracy: 0.3596The average loss for epoch 73 is    0.02
# 78/78 [==============================] - 17s 214ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1779
# 652/652 [==============================] - 108s 165ms/step - loss: 0.0150 - categorical_accuracy: 0.3597
# Epoch 75/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0151 - categorical_accuracy: 0.3591The average loss for epoch 74 is    0.02
# 78/78 [==============================] - 22s 288ms/step - loss: 0.2929 - categorical_accuracy: 0.5881
# 652/652 [==============================] - 114s 174ms/step - loss: 0.0151 - categorical_accuracy: 0.3591
# Epoch 76/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0177 - categorical_accuracy: 0.3892The average loss for epoch 75 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1827
# 652/652 [==============================] - 108s 165ms/step - loss: 0.0176 - categorical_accuracy: 0.3888
# Epoch 77/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0153 - categorical_accuracy: 0.3664The average loss for epoch 76 is    0.02
# 78/78 [==============================] - 19s 245ms/step - loss: 0.2249 - categorical_accuracy: 0.4551
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0153 - categorical_accuracy: 0.3666
# Epoch 78/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0146 - categorical_accuracy: 0.3633The average loss for epoch 77 is    0.01
# 78/78 [==============================] - 17s 217ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1827
# 652/652 [==============================] - 110s 168ms/step - loss: 0.0146 - categorical_accuracy: 0.3631
# Epoch 79/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3689The average loss for epoch 78 is    0.02
# 78/78 [==============================] - 21s 273ms/step - loss: 0.2041 - categorical_accuracy: 0.5032
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0152 - categorical_accuracy: 0.3687
# Epoch 80/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0200 - categorical_accuracy: 0.4051The average loss for epoch 79 is    0.02
# 78/78 [==============================] - 17s 222ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1875
# 652/652 [==============================] - 111s 170ms/step - loss: 0.0200 - categorical_accuracy: 0.4049
# Epoch 81/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0151 - categorical_accuracy: 0.3708The average loss for epoch 80 is    0.02
# 78/78 [==============================] - 20s 255ms/step - loss: 0.2250 - categorical_accuracy: 0.4599
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0151 - categorical_accuracy: 0.3704
# Epoch 82/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3783The average loss for epoch 81 is    0.02
# 78/78 [==============================] - 17s 218ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1939
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0151 - categorical_accuracy: 0.3785
# Epoch 83/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0145 - categorical_accuracy: 0.3731The average loss for epoch 82 is    0.01
# 78/78 [==============================] - 19s 248ms/step - loss: 0.1476 - categorical_accuracy: 0.3622
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0145 - categorical_accuracy: 0.3729
# Epoch 84/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0217 - categorical_accuracy: 0.4268The average loss for epoch 83 is    0.02
# 78/78 [==============================] - 17s 221ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 113s 174ms/step - loss: 0.0217 - categorical_accuracy: 0.4266
# Epoch 85/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3750The average loss for epoch 84 is    0.02
# 78/78 [==============================] - 21s 264ms/step - loss: 0.2035 - categorical_accuracy: 0.4920
# 652/652 [==============================] - 112s 171ms/step - loss: 0.0152 - categorical_accuracy: 0.3744
# Epoch 86/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0154 - categorical_accuracy: 0.3817The average loss for epoch 85 is    0.02
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2003
# 652/652 [==============================] - 108s 166ms/step - loss: 0.0154 - categorical_accuracy: 0.3815
# Epoch 87/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0147 - categorical_accuracy: 0.3813The average loss for epoch 86 is    0.01
# 78/78 [==============================] - 18s 228ms/step - loss: 0.0694 - categorical_accuracy: 0.2692
# 652/652 [==============================] - 110s 169ms/step - loss: 0.0147 - categorical_accuracy: 0.3809
# Epoch 88/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0232 - categorical_accuracy: 0.4510The average loss for epoch 87 is    0.02
# 78/78 [==============================] - 17s 219ms/step - loss: 9.2218e-04 - categorical_accuracy: 0.2051
# 652/652 [==============================] - 115s 177ms/step - loss: 0.0232 - categorical_accuracy: 0.4511
# Epoch 89/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0151 - categorical_accuracy: 0.3846The average loss for epoch 88 is    0.02
# 78/78 [==============================] - 21s 269ms/step - loss: 0.1891 - categorical_accuracy: 0.4856
# 652/652 [==============================] - 113s 174ms/step - loss: 0.0150 - categorical_accuracy: 0.3844
# Epoch 90/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.3906The average loss for epoch 89 is    0.02
# 78/78 [==============================] - 17s 220ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2051
# 652/652 [==============================] - 109s 167ms/step - loss: 0.0152 - categorical_accuracy: 0.3907
# Epoch 91/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0149 - categorical_accuracy: 0.3819The average loss for epoch 90 is    0.01
# 78/78 [==============================] - 18s 228ms/step - loss: 0.0012 - categorical_accuracy: 0.2051
# 652/652 [==============================] - 110s 168ms/step - loss: 0.0149 - categorical_accuracy: 0.3819
# Epoch 92/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0251 - categorical_accuracy: 0.4639The average loss for epoch 91 is    0.03
# 78/78 [==============================] - 17s 221ms/step - loss: 0.0116 - categorical_accuracy: 0.2500
# 652/652 [==============================] - 118s 181ms/step - loss: 0.0253 - categorical_accuracy: 0.4647
# Epoch 93/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0157 - categorical_accuracy: 0.3917The average loss for epoch 92 is    0.02
# 78/78 [==============================] - 20s 251ms/step - loss: 0.1371 - categorical_accuracy: 0.3638
# 652/652 [==============================] - 113s 173ms/step - loss: 0.0157 - categorical_accuracy: 0.3913
# Epoch 94/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0171 - categorical_accuracy: 0.4167The average loss for epoch 93 is    0.02
# 78/78 [==============================] - 18s 224ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2115
# 652/652 [==============================] - 112s 172ms/step - loss: 0.0170 - categorical_accuracy: 0.4166
# Epoch 95/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0156 - categorical_accuracy: 0.4017The average loss for epoch 94 is    0.02
# 78/78 [==============================] - 17s 224ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2147
# 652/652 [==============================] - 111s 171ms/step - loss: 0.0156 - categorical_accuracy: 0.4013
# Epoch 96/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0221 - categorical_accuracy: 0.4499The average loss for epoch 95 is    0.02
# 78/78 [==============================] - 19s 239ms/step - loss: 0.0927 - categorical_accuracy: 0.3718
# 652/652 [==============================] - 119s 182ms/step - loss: 0.0222 - categorical_accuracy: 0.4507
# Epoch 97/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0153 - categorical_accuracy: 0.3990The average loss for epoch 96 is    0.02
# 78/78 [==============================] - 18s 233ms/step - loss: 0.0643 - categorical_accuracy: 0.2564
# 652/652 [==============================] - 113s 174ms/step - loss: 0.0153 - categorical_accuracy: 0.3992
# Epoch 98/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0191 - categorical_accuracy: 0.4330The average loss for epoch 97 is    0.02
# 78/78 [==============================] - 18s 230ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2212
# 652/652 [==============================] - 114s 175ms/step - loss: 0.0190 - categorical_accuracy: 0.4327
# Epoch 99/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0155 - categorical_accuracy: 0.4051The average loss for epoch 98 is    0.02
# 78/78 [==============================] - 20s 257ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2228
# 652/652 [==============================] - 115s 177ms/step - loss: 0.0154 - categorical_accuracy: 0.4053
# Epoch 100/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0202 - categorical_accuracy: 0.4457The average loss for epoch 99 is    0.02
